# %%
import numpy as np
import matplotlib.pylab as plt
from math import exp,log,sqrt,pi,sin
import scipy.stats as sts
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ## Pruebas de Bondad de Ajuste

# %% [markdown]
# ### Kolgomorov - Smirnov
# $D_n=\sup_{-\infty<t<\infty}|F_0(t)-\hat{F}_n(t)|$

# %%
def Dn(F0,X):
    n = len(X)
    Fn = lambda x: ((1/n)*sum([1*(X[i]<=x) for i in range(n)]))
    return max([max(i/n-F0(X[i]),F0(X[i])-(i-1)/n) for i in range(n)])

# %% [markdown]
# ### Cramér-von Mises
# $C_n=\int(F_0(t)-\hat{F}_n(t))^2dF_0(t)$

# %%
def Cn(F0,X):
    n = len(X)
    Fn = lambda x: ((1/n)*sum([1*(X[i]<=x) for i in range(n)]))
    return 1/(12*n) + sum([(F0(X[i])-(2*i-1)/(2*n))**2 for i in range(n)])

# %% [markdown]
# ### Anderson-Darling
# $A_n=\int\frac{(\hat{F}_n(t)-F_0(t))^2}{F_0(t)(1-F_0(t))}dF_0(t)$

# %%
def An(F0,X):
    n = len(X)
    Fn = lambda x: ((1/n)*sum([1*(X[i]<=x) for i in range(n)]))
    return -n-(1/n)*(sum([(2*i-1)*(log(F0(X[i]))+log(1-F0(X[n-i-1]))) for i in range(n)]))

# %%
X = np.random.exponential(2,100)

# %%
p = plt.hist(X,bins=50)

# %%
p = plt.plot(np.linspace(0,9,100),[Fn(x) for x in np.linspace(0,9,100)])
p = plt.plot(np.linspace(0,9,100),[1-exp(-x/2) for x in np.linspace(0,9,100)])

# %%
F0 = lambda x:1-exp(-x/2)

# %%
X.sort()

# %%
Dn = max([max(i/n-F0(X[i]),F0(X[i])-(i-1)/n) for i in range(n)])
Dn
# Out:
# 0.0851969116934278

# %%
Cn = 
Cn
# Out:
# 0.13915094796466357

# %%
An = 
An
# Out:
# -3.491592182755369

# %%
def BB(n):
    T = np.linspace(0,1,n)
    n = len(T)
    B = np.ones(n)*0
    for i in range(n):
        xi = sqrt(2)*np.random.randn()/((i+1)*pi)
        B = B + xi* np.array(list(map(lambda x:sin((i+1)*pi*x),T))) 
    return B

# %%
for _ in range(20):
    plt.plot(np.linspace(0,1,101),abs(BB(101)))

# %%
p = plt.plot(np.linspace(0,9,100),[sqrt(n)*abs(Fn(x)-F0(x)) for x in np.linspace(0,9,100)])

# %%
sim =[]
for _ in range(100):
    sim.append(max(abs(BB(500))))

# %%
S = lambda x =1:1-2*sum([(-1)**(j-1)*exp(-2*(j**2)*(x**2)) for j in range(1,100)])

# %%
p = plt.hist(sim,bins=40,density=True,cumulative=True,alpha=0.7)
p = plt.fill_between(np.linspace(0.2,1.9,100),[S(x) for x in np.linspace(0.2,1.9,100)],color='red',zorder=2,alpha=0.7)

# %%
def KS(X,F,name):
    n = len(X)
    Xi = sorted(X)
    Dn = []
    for i in range(n):
        Dn.append(max((i+1)/n-F(Xi[i]),F(Xi[i])-i/n))
    D = max(Dn)
    K = np.argmax(Dn)
    return D

# %%
def BondadDAjuste(X,alpha):
    n=len(X)
    Fn = lambda y:len([x for x in X if x<=y])/n
    m = np.mean(X)
    v = np.var(X)
    inf = min(X)
    sup = max(X)
    a = m*((m*(1-m))/v-1)
    b = a*(1-m)/m
    b_ = m**2/v
    a_ = m/v
    display(pd.DataFrame([m,v,inf,sup,a,b,a_,b_],index=['$\mu$','$\sigma^2$','$\min$',
                                                        '$\max$','$\\alpha$','$\\beta$','$\\mu/\\sigma^{2}$',
                                                        '$\\mu^{2}/\\sigma^{2}$']).T)
    F = {'Normal':lambda x:sts.norm.cdf(x,m,v),
        'Exponencial':lambda x:sts.expon.cdf(x,0,m),
        'Uniforme':lambda x:sts.uniform.cdf(x,inf,sup),
        'Beta':lambda x:sts.beta.cdf(x,a,b),
        'Gamma':lambda x:sts.gamma.cdf(x,a_,0,b_)}
    t = np.arange(inf,sup+0.02,0.01)
    plt.figure(figsize=(16,9))
    Graficas = [plt.plot(t,F[x](t),label=x) for x in F.keys()]
    plt.step(t,list(map(Fn,t)),label='Empirica',lw=2,color='black')
    plt.title('Pruebas de bondad de ajuste')
    plt.legend()
    nDn =lambda l=1:1-2*sum(((-1)**(j-1))*exp(-2*(j**2)*(l**2)) for j in range(1,300))
    Quant = lambda alpha:max(q for q in np.arange(0.01,4,0.01) if nDn(q)<alpha)
    KSs = {x:KS(X,F[x],x) for x in F.keys()}
    Calc = {x:[KSs[x],sqrt(n)*KSs[x],Quant(alpha),sqrt(n)*KSs[x]<=Quant(alpha)] for x in F.keys()}
    display(pd.DataFrame(Calc,index=['$D_n$','$\sqrt{n}D_n$','$q_{%s}$'%alpha,'$H_0$']).T)

# %%
BondadDAjuste(np.random.exponential(3,100),0.15)
# Out:
#       $\mu$  $\sigma^2$    $\min$     $\max$  $\alpha$   $\beta$  \
# 0  3.581033   14.896242  0.013913  19.601276 -5.802978  4.182502
#
#    $\mu/\sigma^{2}$  $\mu^{2}/\sigma^{2}$
# 0          0.240398              0.860874
#                  $D_n$ $\sqrt{n}D_n$ $q_{0.15}$  $H_0$
# Normal        0.405373       4.05373       0.61  False
# Exponencial  0.0735097      0.735097       0.61  False
# Uniforme       0.53645        5.3645       0.61  False
# Beta               NaN           NaN       0.61  False
# Gamma         0.750755       7.50755       0.61  False

# %%
X= np.random.exponential(2,20)
n = len(X)
def Fn(x):
    return((1/n)*sum([1*(X[i]<=x) for i in range(n)]))

# %%
plt.figure(figsize=(16,9))
X.sort()
p = plt.step(X,Fn(X),where='pre')
p = plt.step(X,Fn(X),where='mid')
p = plt.step(X,Fn(X),where='post')
